# %% [markdown]
# # XGBoost model cross-validationLoad the processed model matrix and evaluate using the 10-fold chronological scheme.

# %%
import pandas as pdfrom xgboost import XGBRegressorfrom utils import default_catalog, load_table, evaluate_time_series_modelcatalog = default_catalog()model_matrix_path = catalog['model_matrix']

# %% [markdown]
# ## Load featuresThe model matrix should be generated from the data-cleaning notebook.

# %%
if model_matrix_path.exists():    dataset = load_table(model_matrix_path)    target = dataset['target']    features = dataset.drop(columns=['target'])else:    dataset = None    print(f"Model matrix not found at {model_matrix_path}.")

# %% [markdown]
# ## Evaluate with the Hull Sharpe metric

# %%
if dataset is not None:    avg_score, fold_scores = evaluate_time_series_model(        features,        target,        estimator_factory=lambda: XGBRegressor(            n_estimators=500,            max_depth=6,            learning_rate=0.05,            subsample=0.8,            colsample_bytree=0.8,            objective='reg:squarederror',            eval_metric='rmse',        ),        date_col='date',    )    print(f"Average Sharpe-style score: {avg_score:.4f}")    print(f"Fold scores: {[round(s, 4) for s in fold_scores]}")else:    print('Skipping evaluation until the model matrix exists.')
